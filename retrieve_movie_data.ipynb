# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")
# Out:
# OXpxqegQTnXjbXQiCsR5APYHAT2SB3th

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = url + "api-key=" + nyt_api_key + "&fq=" + filter_query + "&sort=" + sort + "&begin_date=" + begin_date + "&end_date=" + end_date + "&fl=" + field_list
print(query_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=OXpxqegQTnXjbXQiCsR5APYHAT2SB3th&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&sort=newest&begin_date=20130101&end_date=20230531&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range (0,20):
    query_url = url + "api-key=" + nyt_api_key + "&fq=" + filter_query + "&sort=" + sort + "&begin_date=" + begin_date + "&end_date=" + end_date + "&fl=" + field_list
    # create query with a page number
    # API results show 10 articles at a time
    query_url2 = f"{query_url}&page={str(page)}"
    
    # Make a "GET" request and retrieve the JSON
    reviews = requests.get(query_url2).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)
        # Print the page that was just retrieved
        print(f"Checked page {page}")
    except:
        # Print the page number that had no results then break from the loop
        print(f"Page {page} has no results")
        break
# Out:
# Checked page 0
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
counter = 0
while counter < 5:
    print(json.dumps(reviews_list[counter], indent=4))
    counter += 1
# Out:
# {
#     "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#     "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#     "source": "The New York Times",
#     "headline": {
#         "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#         "kicker": null,
#         "content_kicker": null,
#         "print_headline": "The Attachment Diaries",
#         "name": null,
#         "seo": null,
#         "sub": null
#     },
#     "keywords": [
#         {
#             "name": "subject",
#             "value": "Movies",
#             "rank": 1,
#             "major": "N"
#         },
#         {
#             "name": "creative_works",
#             "value": "The Attachment Diaries (Movie)",
#             "rank": 2,
#             "major": "N"
#         },
#         {
#             "name": "persons",
#             "value": "Diment, Valentin Javier",
# ...

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df["title"] = reviews_df["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df["keywords"] = reviews_df["keywords"].apply(extract_keywords)
reviews_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
titles = reviews_df["title"].to_list()
titles
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
# ...

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
for i in titles:
    print(i)
    print(url + i + tmdb_key_string)
# Out:
# The Attachment Diaries
# https://api.themoviedb.org/3/search/movie?query=The Attachment Diaries&api_key=5be7cefda8859084e5f2b29b8b338380
# What’s Love Got to Do With It?’ Probably a Lo
# https://api.themoviedb.org/3/search/movie?query=What’s Love Got to Do With It?’ Probably a Lo&api_key=5be7cefda8859084e5f2b29b8b338380
# You Can Live Forever
# https://api.themoviedb.org/3/search/movie?query=You Can Live Forever&api_key=5be7cefda8859084e5f2b29b8b338380
# A Tourist’s Guide to Love
# https://api.themoviedb.org/3/search/movie?query=A Tourist’s Guide to Love&api_key=5be7cefda8859084e5f2b29b8b338380
# Other People’s Children
# https://api.themoviedb.org/3/search/movie?query=Other People’s Children&api_key=5be7cefda8859084e5f2b29b8b338380
# One True Loves
# https://api.themoviedb.org/3/search/movie?query=One True Loves&api_key=5be7cefda8859084e5f2b29b8b338380
# The Lost Weekend: A Love Story
# ...

# %%
tmdb_movies_list = []
genre_names_list = []
spoken_languages_list = []
production_countries_list = []


request_counter = 1

for i in titles:
    if request_counter % 50 == 0:
        time.sleep(1)
        print(f"Sleeping at {request_counter} requests")
    else:
        response_data = requests.get(url + i + tmdb_key_string).json()
        try:
            movie_id = response_data["results"][0]["id"]
            details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
            details_response_data = requests.get(details_url).json()
            print(f"Found {i} + {movie_id}")
        except:
            print(f"{i} not found.")
            pass
    request_counter += 1
# Out:
# Found The Attachment Diaries + 743040
# What’s Love Got to Do With It?’ Probably a Lo not found.
# Found You Can Live Forever + 887580
# Found A Tourist’s Guide to Love + 813726
# Found Other People’s Children + 803694
# Found One True Loves + 846961
# Found The Lost Weekend: A Love Story + 965042
# Found A Thousand and One + 855263
# Found Your Place or Mine + 703451
# Found Love in the Time of Fentanyl + 976653
# Found Pamela, a Love Story + 1061671
# Found In From the Side + 622082
# Found After Love + 714011
# Found Alcarràs + 804251
# Found Nelly & Nadine + 12652
# Found Lady Chatterley’s Lover + 814338
# Found The Sound of Christmas + 1035923
# Found The Inspection + 837938
# Found Bones and All + 791177
# Found My Policeman + 744114
# Found About Fate + 828613
# Found Waiting for Bojangles + 851303
# Found I Love My Dad + 876825
# Found A Love Song + 913851
# Found Alone Together + 826113
# Found Art of Love + 92424
# Found The Wheel + 630737
# ...

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1

# Loop through the titles
for i in titles:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        time.sleep(1)
        print(f"Sleeping at {request_counter} requests")
    # Add 1 to the request counter
    request_counter += 1

    # Perform a "GET" request for The Movie Database
    response_data = requests.get(url + i + tmdb_key_string).json()

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        # Get movie id
        movie_id = response_data["results"][0]["id"]

        # Make a request for a the full movie details
        details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"

        # Execute "GET" request with url
        details_response_data = requests.get(details_url).json()
        
        # Extract the genre names into a list
        genres = []
        for x in details_response_data["genres"]:
            genres.append(x["name"])

        # Extract the spoken_languages' English name into a list
        spoken_languages = []
        for y in details_response_data["spoken_languages"]:
            spoken_languages.append(y["english_name"])

        # Extract the production_countries' name into a list
        production_countries = []
        for z in details_response_data["production_countries"]:
            production_countries.append(z["name"])

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        movie_data = {
            "title": details_response_data["title"],
            "original_title": details_response_data["original_title"],
            "budget": details_response_data["budget"],
            "original_language": details_response_data["original_language"],
            "homepage": details_response_data["homepage"],
            "overview": details_response_data["overview"],
            "popularity": details_response_data["popularity"],
            "runtime": details_response_data["runtime"],
            "revenue": details_response_data["revenue"],
            "release_date": details_response_data["release_date"],
            "vote_average": details_response_data["vote_average"],
            "vote_count": details_response_data["vote_count"],
            "genres": genres,
            "spoken_languages": spoken_languages,
            "production_countries": production_countries
        }
        tmdb_movies_list.append(movie_data)
        # Print out the title that was found
        print(f"Found {i}")
    except:
        print(f"{i} not found.")
        pass
# Out:
# Found The Attachment Diaries
# What’s Love Got to Do With It?’ Probably a Lo not found.
# Found You Can Live Forever
# Found A Tourist’s Guide to Love
# Found Other People’s Children
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found About Fate
# Found Waiting for Bojangles
# Found I Love My Dad
# Found A Love Song
# Found Alone Together
# Found Art of Love
# Found The Wheel
# Found Thor: Love and Thunder
# Found Both Sides of the Blade
# Found Fire of Love
# Found Love & Gelato
# Found Stay Prayed Up
# Found Benediction
# Found Dinner in America
# Found In a New York Minute
# Found Anaïs in Love
# Found I Love America
# ...

# %%
movies_df = pd.json_normalize(tmdb_movies_list)
movies_df
# Out:
#                          title             original_title    budget  \
# 0       The Attachment Diaries                   El apego         0
# 1         You Can Live Forever       You Can Live Forever         0
# 2    A Tourist's Guide to Love  A Tourist's Guide to Love         0
# 3      Other People's Children     Les Enfants des autres         0
# 4               One True Loves             One True Loves         0
# ..                         ...                        ...       ...
# 149              The Last Face              The Last Face         0
# 150              Lost in Paris            Paris pieds nus         0
# 151             The Other Half             The Other Half         0
# 152     The Ottoman Lieutenant     The Ottoman Lieutenant  40000000
# 153            Long Live Love!             ลอง ลีฟ เลิฟว์         0
#
#     original_language                                           homepage  \
# 0                  es
# ...

# %%
response_data2 = requests.get(url + "The Attachment Diaries" + tmdb_key_string).json()
#print(json.dumps(response_data2, indent=4))
movie_id = response_data2["results"][0]["id"]
#print(movie_id)
details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
details_response_data = requests.get(details_url).json()
print(json.dumps(details_response_data, indent = 4))
genre_list = []
for i in details_response_data['genres']:
    genre_list.append(i['name'])
    print(i)
    print(i["name"])
#print(genre_list)
# Out:
# {
#     "adult": false,
#     "backdrop_path": null,
#     "belongs_to_collection": null,
#     "budget": 0,
#     "genres": [
#         {
#             "id": 18,
#             "name": "Drama"
#         },
#         {
#             "id": 9648,
#             "name": "Mystery"
#         },
#         {
#             "id": 53,
#             "name": "Thriller"
#         },
#         {
#             "id": 27,
#             "name": "Horror"
#         }
#     ],
#     "homepage": "",
#     "id": 743040,
#     "imdb_id": "tt11359158",
#     "original_language": "es",
#     "original_title": "El apego",
# ...

# %%
# Create an empty list to store the results


# Create a request counter to sleep the requests after a multiple
# of 50 requests


# Loop through the titles

    # Check if we need to sleep before making a request


    # Add 1 to the request counter

    
    # Perform a "GET" request for The Movie Database


    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.

        # Get movie id


        # Make a request for a the full movie details


        # Execute "GET" request with url

        
        # Extract the genre names into a list


        # Extract the spoken_languages' English name into a list


        # Extract the production_countries' name into a list


        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list

        
        # Print out the title that was found
# Out:
# Found The Attachment Diaries
# What’s Love Got to Do With It?’ Probably a Lo not found.
# Found You Can Live Forever
# Found A Tourist’s Guide to Love
# Found Other People’s Children
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found About Fate
# Found Waiting for Bojangles
# Found I Love My Dad
# Found A Love Song
# Found Alone Together
# Found Art of Love
# Found The Wheel
# Found Thor: Love and Thunder
# Found Both Sides of the Blade
# Found Fire of Love
# Found Love & Gelato
# Found Stay Prayed Up
# Found Benediction
# Found Dinner in America
# Found In a New York Minute
# Found Anaïs in Love
# Found I Love America
# ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "genre": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "language": "es",
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 0.708,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 4.0,
#         "vote_count": 2,
# ...

# %%
# Convert the results to a DataFrame
# Out:
#                          title             original_title    budget  \
# 0       The Attachment Diaries                   El apego         0
# 1         You Can Live Forever       You Can Live Forever         0
# 2    A Tourist's Guide to Love  A Tourist's Guide to Love         0
# 3      Other People's Children     Les Enfants des autres         0
# 4               One True Loves             One True Loves         0
# ..                         ...                        ...       ...
# 150              The Last Face              The Last Face         0
# 151              Lost in Paris            Paris pieds nus         0
# 152             The Other Half             The Other Half         0
# 153     The Ottoman Lieutenant     The Ottoman Lieutenant  40000000
# 154             Rich in Love 2            Ricos de Amor 2         0
#
#                                   genre language       spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]       es              [Spanish]
# ...

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
# Out:
#                               title                  original_title    budget  \
# 0            The Attachment Diaries                        El apego         0
# 1              You Can Live Forever            You Can Live Forever         0
# 2                    One True Loves                  One True Loves         0
# 3    The Lost Weekend: A Love Story  The Lost Weekend: A Love Story         0
# 4                A Thousand and One              A Thousand and One         0
# ..                              ...                             ...       ...
# 120            In Search of Fellini            In Search of Fellini         0
# 121                   The Last Face                   The Last Face         0
# 122                   Lost in Paris                 Paris pieds nus         0
# 123                  The Other Half                  The Other Half         0
# 124          The Ottoman Lieutenant          The Ottoman Lieutenant  40000000
#
# ...

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# ...

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# ...

# %%
# Export data to CSV without the index
