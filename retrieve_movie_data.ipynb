# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")
# Out:
# OXpxqegQTnXjbXQiCsR5APYHAT2SB3th

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
query = 'love'
section_name = '("movies")'
type_of_material = '("review")'
headline = '("love")'
filter_query = f"&fq=headline:{headline}&fq=section_name:{section_name}&fq=type_of_material:{type_of_material}"

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = url + "api-key=" + nyt_api_key + "&q=" + query + filter_query + "&sort=" + sort + "&begin_date=" + begin_date + "&end_date=" + end_date + "&fl=" + field_list
print(query_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=OXpxqegQTnXjbXQiCsR5APYHAT2SB3th&q=love&fq=headline:("love")&fq=section_name:("movies")&fq=type_of_material:("review")&sort=newest&begin_date=20130101&end_date=20230531&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count

# %%
reviews_list = []

for page in range (0,20):
    query_url = url + "api-key=" + nyt_api_key + "&q=" + query + filter_query + "&sort=" + sort + "&begin_date=" + begin_date + "&end_date=" + end_date + "&fl=" + field_list
    
    query_url2 = f"{query_url}&page={str(page)}"
    reviews = requests.get(query_url2).json()
    
    time.sleep(12)
    
    try:
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)
        print(f"Checked page {page}")
    except:
        print("")
# Out:
# Checked page 0
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19

# %%
print(json.dumps(reviews_list, indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/30/style/tiny-modern-love-stories-everyone-knew-but-him.html",
#         "snippet": "Modern Love in miniature, featuring reader-submitted stories of no more than 100 words.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Tiny Love Stories: \u2018Everyone Knew but Him\u2019",
#             "kicker": "Modern Love",
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Love (Emotion)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Modern Love (Times Column)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Dating and Relationships",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Loneliness",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Mixed Martial Arts",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-30T19:00:20+0000",
#         "byline": {
#             "original": null,
#             "person": [],
#             "organization": null
#         },
#         "word_count": 484
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/30/theater/here-lies-love-david-byrne-musicians.html",
#         "snippet": "The show plans to use recorded music instead of a live band, but a labor union says its contract for the theater requires musicians for musicals.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Broadway Musicians Object to David Byrne\u2019s \u2018Here Lies Love\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Broadway Musicians Object to David Byrne\u2019s \u2018Here Lies Love\u2019",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Theater",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Theater (Broadway)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Here Lies Love (Play)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Byrne, David",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Pop and Rock Music",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Broadway League",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Organized Labor",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "American Federation of Musicians",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Audio Recordings, Downloads and Streaming",
#                 "rank": 9,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-30T17:01:03+0000",
#         "byline": {
#             "original": "By Michael Paulson",
#             "person": [
#                 {
#                     "firstname": "Michael",
#                     "middlename": null,
#                     "lastname": "Paulson",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 600
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/26/us/ken-paxton-texas.html",
#         "snippet": "With the Texas House set to vote on his impeachment, Mr. Paxton is counting on political support that he\u2019s amassed as a Republican legal firebrand.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "How Fighting for Conservative Causes Has Helped Ken Paxton Survive Legal Woes",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Right\u2019s Love Helps a Texas Official in a Bind",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "persons",
#                 "value": "Paxton, Ken",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Impeachment",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "State Legislatures",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Attorneys General",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Conservatism (US Politics)",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Austin (Tex)",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Texas",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Workplace Hazards and Violations",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Politics and Government",
#                 "rank": 9,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Ethics and Official Misconduct",
#                 "rank": 10,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Republican Party",
#                 "rank": 11,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-26T23:36:08+0000",
#         "byline": {
#             "original": "By J. David Goodman",
#             "person": [
#                 {
#                     "firstname": "J.",
#                     "middlename": "David",
#                     "lastname": "Goodman",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1532
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/26/style/love-letter-newsletter-not-part-of-the-plan.html",
#         "snippet": "\u201cThat\u2019s why I picked a younger man; he wouldn\u2019t do to me what your father did.\u201d",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Love Letter: Not Part of the Plan",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Dating and Relationships",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Love (Emotion)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cattrall, Kim",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Tribeca Film Festival (NYC)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-26T20:41:20+0000",
#         "byline": {
#             "original": "By Miya Lee",
#             "person": [
#                 {
#                     "firstname": "Miya",
#                     "middlename": null,
#                     "lastname": "Lee",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 148
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/26/theater/aspects-of-love-lyric-theater-london.html",
#         "snippet": "A London revival of Andrew Lloyd Webber\u2019s partner-swapping musical is a camp amoral romp. But is this obsession really the same as romance?",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: Problematic Attachments in \u2018Aspects of Love\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Theater",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Aspects of Love (Play)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Lyric Theater",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ball, Michael (1962- )",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lloyd Webber, Andrew",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "London (England)",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "de Niese, Danielle",
#                 "rank": 7,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-26T15:55:52+0000",
#         "byline": {
#             "original": "By Houman Barekat",
#             "person": [
#                 {
#                     "firstname": "Houman",
#                     "middlename": null,
#                     "lastname": "Barekat",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 800
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/26/style/tristan-thompson-tyla-wade-wedding.html",
#         "snippet": "Tristan Thompson and Tyla Wade\u2019s passion for their community was the inspiration for their podcast \u201cBlack Love is Resistance\u201d and their wedding celebration that featured mostly Black vendors.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "A Union That Felt Like \u2018a Love Letter to Black Culture\u2019",
#             "kicker": "Vows",
#             "content_kicker": null,
#             "print_headline": "Their Union Felt Like \u2018a Love Letter to Black Culture\u2019",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Weddings and Engagements",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Black People",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Blacks",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-26T04:00:41+0000",
#         "byline": {
#             "original": "By Sadiba Hasan",
#             "person": [
#                 {
#                     "firstname": "Sadiba",
#                     "middlename": null,
#                     "lastname": "Hasan",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1661
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/arts/music/pete-brown-dead.html",
#         "snippet": "A British Beat poet, he wrote lyrics for the band Cream and, after it broke up, continued to collaborate with Jack Bruce, the group\u2019s lead singer and bassist.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Pete Brown, Who Put Words to \u2018Sunshine of Your Love,\u2019 Dies at 82",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Pete Brown, 82, Poet   Who Wrote the Lyrics To Cream\u2019s Hits, Dies",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "persons",
#                 "value": "Brown, Pete (1940-2023)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Deaths (Obituaries)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Poetry and Poets",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Pop and Rock Music",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Nineteen Hundred Sixties",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Cream (Music Group)",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Baker, Ginger",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bruce, Jack (1943-2014)",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Clapton, Eric",
#                 "rank": 9,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Great Britain",
#                 "rank": 10,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T20:01:09+0000",
#         "byline": {
#             "original": "By Richard Sandomir",
#             "person": [
#                 {
#                     "firstname": "Richard",
#                     "middlename": null,
#                     "lastname": "Sandomir",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1154
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/arts/music/salvatore-sciarrino-opera.html",
#         "snippet": "Salvatore Sciarrino\u2019s \u201cVenere e Adone,\u201d his 15th opera, premieres this weekend at the Hamburg State Opera.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "An Opera Composer of Intimate Spareness Returns to Myth",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "When Love Takes Aim At a Monster",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Opera",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Sciarrino, Salvatore",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Hamburg State Opera",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Hamburg (Germany)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Venere e Adone (Opera)",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T19:26:36+0000",
#         "byline": {
#             "original": "By Jeffrey Arlo Brown",
#             "person": [
#                 {
#                     "firstname": "Jeffrey",
#                     "middlename": "Arlo",
#                     "lastname": "Brown",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1216
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/books/review/brandon-taylor-interview.html",
#         "snippet": "\u201cIndeed, the two have a lot in common!\u201d says the author, whose new novel is \u201cThe Late Americans.\u201d",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Brandon Taylor Loves to Read Romances and European History",
#             "kicker": "By the Book",
#             "content_kicker": null,
#             "print_headline": "Brandon Taylor",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Books and Literature",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Writing and Writers",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Taylor, Brandon (Author)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T09:00:09+0000",
#         "byline": {
#             "original": null,
#             "person": [],
#             "organization": null
#         },
#         "word_count": 1127
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/23/style/tiny-modern-love-stories-i-never-saw-my-parents-kiss.html",
#         "snippet": "Modern Love in miniature, featuring reader-submitted stories of no more than 100 words.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Tiny Love Stories: \u2018I Never Saw My Parents Kiss\u2019",
#             "kicker": "Modern Love",
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Love (Emotion)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Modern Love (Times Column)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Dating and Relationships",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Homosexuality and Bisexuality",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Drag (Performance)",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Bars and Nightclubs",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Families and Family Life",
#                 "rank": 7,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-23T19:02:45+0000",
#         "byline": {
#             "original": null,
#             "person": [],
#             "organization": null
#         },
#         "word_count": 481
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/23/world/europe/belarus-roman-protasevich-pardon.html",
#         "snippet": "Roman Protasevich became a symbol of the struggle for democracy when Belarus forced down a plane and arrested him. Now it has pardoned him, and former allies say he has turned on them.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Belarus Turns a Story of Love and Protest Into a Tale of Betrayal",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "From Dissident Hero to a Pardoned Villain",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "glocations",
#                 "value": "Belarus",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Political Prisoners",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Protasevich, Roman",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Sapega, Sofia",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lukashenko, Aleksandr G",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Demonstrations, Protests and Riots",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Democracy (Theory and Philosophy)",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "State Security Committee (KGB) (Belarus)",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Politics and Government",
#                 "rank": 9,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Human Rights and Human Rights Violations",
#                 "rank": 10,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-23T13:59:55+0000",
#         "byline": {
#             "original": "By Andrew Higgins",
#             "person": [
#                 {
#                     "firstname": "Andrew",
#                     "middlename": null,
#                     "lastname": "Higgins",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1445
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/23/travel/guatemala-joyce-maynard-hotel.html",
#         "snippet": "\u201cThese days, my role as an innkeeper occupies me almost as much as fiction,\u201d writes Joyce Maynard, who, during the pandemic, hired locals in a Guatemalan village to turn her writing retreat into a guesthouse.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "The Accidental Innkeeper: How an American Novelist Became a Hotelier in Guatemala",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Novelist Falls in Love (With a Country)",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Travel and Vacations",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Hotels and Travel Lodgings",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Guatemala",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Lake Atitlan (Guatemala)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Writing and Writers",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Maynard, Joyce",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 7,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-23T09:00:34+0000",
#         "byline": {
#             "original": "By Joyce Maynard",
#             "person": [
#                 {
#                     "firstname": "Joyce",
#                     "middlename": null,
#                     "lastname": "Maynard",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 2059
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/22/theater/bees-and-honey-review.html",
#         "snippet": "In this play by Guadal\u00eds Del Carmen, a couple\u2019s shared heritage is integral to their meeting and the ups and downs of their daily relationship.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: In \u2018Bees & Honey,\u2019 Love Is Both Sweet and Sticky",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Rhythms of a Love Are Sweet and Sticky",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Theater",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "MCC Theater Company",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Sol Project",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Bees and Honey (Play)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-22T23:00:06+0000",
#         "byline": {
#             "original": "By Naveen Kumar",
#             "person": [
#                 {
#                     "firstname": "Naveen",
#                     "middlename": null,
#                     "lastname": "Kumar",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 479
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/22/arts/music/review-stranger-love-los-angeles-philharmonic.html",
#         "snippet": "The premiere of Dylan Mattingly and Thomas Bartscherer\u2019s six-hour opera was presented by the orchestra \u2014 an institution at an inflection point.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Stranger Love\u2019 Reflects the L.A. Philharmonic at Its Finest",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "Six Hours of Ambition and Magnitude",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Opera",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Contemporaneous (Music Group)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Disney, Walt, Concert Hall",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Los Angeles Philharmonic",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Blain-Cruz, Lileana",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Mattingly, Dylan (1991- )",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Stranger Love (Opera)",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Los Angeles (Calif)",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-22T17:07:24+0000",
#         "byline": {
#             "original": "By Joshua Barone",
#             "person": [
#                 {
#                     "firstname": "Joshua",
#                     "middlename": null,
#                     "lastname": "Barone",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1169
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/22/arts/music/dave-matthews-band-walk-around-the-moon-review.html",
#         "snippet": "\u201cWalk Around the Moon,\u201d the group\u2019s 10th album, faces troubles and searches for solace.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Dave Matthews Band\u2019s Grown-Up View of Love and Dread",
#             "kicker": "Album Review",
#             "content_kicker": null,
#             "print_headline": "A Grown-Up View Of Love and Dread",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Pop and Rock Music",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Dave Matthews Band",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Matthews, Dave",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Walk Around the Moon (Album)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-22T16:05:13+0000",
#         "byline": {
#             "original": "By Jon Pareles",
#             "person": [
#                 {
#                     "firstname": "Jon",
#                     "middlename": null,
#                     "lastname": "Pareles",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 660
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/19/style/love-letter-newsletter-the-decision-after-an-affair.html",
#         "snippet": "\u201cFrom spring to summer, we debated whether to tell our spouses, the harm we would cause by leaving them, the happiness we might miss if we didn\u2019t.\u201d",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Love Letter: The Decision After an Affair",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Adultery",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Dating and Relationships",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Happiness",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Love (Emotion)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-19T20:56:52+0000",
#         "byline": {
#             "original": "By Miya Lee",
#             "person": [
#                 {
#                     "firstname": "Miya",
#                     "middlename": null,
#                     "lastname": "Lee",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 146
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/19/style/donald-brown-jennifer-kizza-wedding.html",
#         "snippet": "Jennifer Kizza and Field Brown felt an immediate connection during their first phone conversation two years ago. \u201cI knew that day, romantic or not, Field was going to be in my life for the rest of my life,\u201d she said.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "One Call, and Many Virtual Dates Later, They Found Love",
#             "kicker": "mini-vows",
#             "content_kicker": null,
#             "print_headline": "One Call and Many Virtual Dates Later, It\u2019s a Match",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Weddings and Engagements",
#                 "rank": 1,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-19T04:00:08+0000",
#         "byline": {
#             "original": "By Nia Decaille",
#             "person": [
#                 {
#                     "firstname": "Nia",
#                     "middlename": null,
#                     "lastname": "Decaille",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 864
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/18/us/california-love-letters.html",
#         "snippet": "Tributes to quaint beach towns, diverse neighborhoods and more.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "You Shared What You Love About California",
#             "kicker": "California Today",
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "glocations",
#                 "value": "California",
#                 "rank": 1,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-18T13:00:10+0000",
#         "byline": {
#             "original": "By Soumya Karlamangla",
#             "person": [
#                 {
#                     "firstname": "Soumya",
#                     "middlename": null,
#                     "lastname": "Karlamangla",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1189
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/17/opinion/trump-desantis-2024.html",
#         "snippet": "It\u2019s hard to imagine the Trump and DeSantis families getting together for a cookout.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Remember When Trump and DeSantis Loved Each Other? Neither Do They.",
#             "kicker": "Gail Collins",
#             "content_kicker": null,
#             "print_headline": "Trump and DeSantis Loved Each Other Once",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Elections",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Politics and Government",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Law and Legislation",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Abortion",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Republican Party",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Primaries and Caucuses",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Presidential Election of 2024",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "DeSantis, Ron",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Trump, Donald J",
#                 "rank": 9,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-17T23:39:36+0000",
#         "byline": {
#             "original": "By Gail Collins",
#             "person": [
#                 {
#                     "firstname": "Gail",
#                     "middlename": null,
#                     "lastname": "Collins",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 916
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/16/style/tiny-modern-love-stories-deeply-in-love-with-a-polyamorous-woman.html",
#         "snippet": "Modern Love in miniature, featuring reader-submitted stories of no more than 100 words.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Tiny Love Stories: \u2018Deeply in Love With a Polyamorous Woman\u2019",
#             "kicker": "Modern Love",
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Love (Emotion)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Modern Love (Times Column)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Dating and Relationships",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Polyamory and Non-Monogamous Relationships",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-16T20:09:48+0000",
#         "byline": {
#             "original": null,
#             "person": [],
#             "organization": null
#         },
#         "word_count": 487
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/16/style/writers-strike-romance.html",
#         "snippet": "In Los Angeles, movie and TV writers on strike are eyeing one another with more than solidarity on their minds.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "What Do We Want? Love! When Do We Want It? Now!",
#             "kicker": "Third Wheel",
#             "content_kicker": null,
#             "print_headline": "Picketing, With More Than a Contract on Their Minds",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Dating and Relationships",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Writing and Writers",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Writers Guild of America",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Los Angeles (Calif)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Single Persons",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Strikes",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-16T19:10:33+0000",
#         "byline": {
#             "original": "By Gina Cherelus",
#             "person": [
#                 {
#                     "firstname": "Gina",
#                     "middlename": null,
#                     "lastname": "Cherelus",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1749
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/16/magazine/bilingual-editions.html",
#         "snippet": "Treat language as a Jenga tower, moving its pieces but preserving its structure.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "You Don\u2019t Need to Speak Another Language to Love a Bilingual Edition",
#             "kicker": "Letter of Recommendation",
#             "content_kicker": null,
#             "print_headline": "Bilingual Editions",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Books and Literature",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
# ...
#         "headline": {
#             "main": "Kenji L\u00f3pez-Alt\u2019s Family Loves This Soup. Here\u2019s How He Made It Easier.",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Less Labor for the Same Great Flavor",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Cooking and Cookbooks",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Squash (Vegetable)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Soups",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-10T19:06:32+0000",
#         "byline": {
#             "original": "By J. Kenji L\u00f3pez-Alt",
#             "person": [
#                 {
#                     "firstname": "J.",
#                     "middlename": "Kenji",
#                     "lastname": "L\u00f3pez-Alt",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 685
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/10/dining/love-and-scallops.html",
#         "snippet": "Scallops may be a little fancier than most everyday ingredients, but Melissa Clark\u2019s creamy preparation couldn\u2019t be easier.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Love and Scallops",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Cooking and Cookbooks",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Service",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Recipes",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-10T18:00:05+0000",
#         "byline": {
#             "original": "By Emily Weinstein",
#             "person": [
#                 {
#                     "firstname": "Emily",
#                     "middlename": null,
#                     "lastname": "Weinstein",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 575
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/10/realestate/couples-separate-bedrooms.html",
#         "snippet": "Snoring and conflicting schedules are top reasons couples decide to sleep in separate bedrooms. Sex therapists and marriage counselors have their doubts about the arrangement.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "I Love You, but I Don\u2019t Want to Sleep With You",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Love? Together. Sleep? Apart.",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Marriages",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Dating and Relationships",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Sleep",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Love (Emotion)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Snoring",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "United States",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "internal-sub-only",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-10T10:00:20+0000",
#         "byline": {
#             "original": "By Ronda Kaysen",
#             "person": [
#                 {
#                     "firstname": "Ronda",
#                     "middlename": null,
#                     "lastname": "Kaysen",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 2125
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/10/style/flower-delivery-card-messages.html",
#         "snippet": "Prewritten messages offered by flower-delivery services spare customers the hassle of having to put their feelings into words.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Leave \u2018I Love You\u2019 to the Pros",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Say It With Flowers And a Prewritten Note",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Gifts",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Flowers and Plants",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Valentine's Day",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Love (Emotion)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Teleflora",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-10T10:00:18+0000",
#         "byline": {
#             "original": "By Callie Holtermann",
#             "person": [
#                 {
#                     "firstname": "Callie",
#                     "middlename": null,
#                     "lastname": "Holtermann",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 814
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/10/learning/young-love.html",
#         "snippet": "Tell us a story, real or made up, that is inspired by this image.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Young Love",
#             "kicker": "Picture Prompts",
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [],
#         "pub_date": "2023-02-10T08:00:02+0000",
#         "byline": {
#             "original": "By The Learning Network",
#             "person": [],
#             "organization": "The Learning Network"
#         },
#         "word_count": 119
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/09/movies/your-place-or-mine-review.html",
#         "snippet": "This humdrum Netflix romantic comedy features Reese Witherspoon and Ashton Kutcher as longtime friends with possibly hidden feelings for each other.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Your Place or Mine\u2019 Review: Try Neither",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "They Have a Humdrum Kind of Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Your Place or Mine (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Witherspoon, Reese",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kutcher, Ashton",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McKenna, Aline Brosh",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-10T00:00:05+0000",
#         "byline": {
#             "original": "By Amy Nicholson",
#             "person": [
#                 {
#                     "firstname": "Amy",
#                     "middlename": null,
#                     "lastname": "Nicholson",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 569
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/09/opinion/relationship-identity-mindset-marriage.html",
#         "snippet": "Togetherness didn\u2019t come naturally to me. But it can be learned.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "What I Know About Married Bliss I Learned From My Husband\u2019s Twin",
#             "kicker": "Guest Essay",
#             "content_kicker": null,
#             "print_headline": "Going From \u2018Me\u2019 to \u2018We,\u2019 The Hardest Part of Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Marriages",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Dating and Relationships",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Twins",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Love (Emotion)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-09T10:00:17+0000",
#         "byline": {
#             "original": "By Michal Leibowitz",
#             "person": [
#                 {
#                     "firstname": "Michal",
#                     "middlename": null,
#                     "lastname": "Leibowitz",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1507
#     },
#     {
#         "web_url": "https://www.nytimes.com/interactive/2023/02/09/opinion/transgender-americans-focus-group.html",
#         "snippet": "A group of transgender Americans describes what it\u2019s like to be trans in America today.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "These 12 Transgender Americans Would Love You to Mind Your Own Business",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "12 Trans Americans On Transgender Rights",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Transgender",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "United States Politics and Government",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Polls and Public Opinion",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Discrimination",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "United States",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-09T06:00:01+0000",
#         "byline": {
#             "original": "By Patrick Healy and Adrian J. Rivera",
#             "person": [
#                 {
#                     "firstname": "Patrick",
#                     "middlename": null,
#                     "lastname": "Healy",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 },
#                 {
#                     "firstname": "Adrian",
#                     "middlename": "J.",
#                     "lastname": "Rivera",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 2
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 0
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/02/07/style/tiny-modern-love-stories-my-parents-fought-a-lot.html",
#         "snippet": "Modern Love in miniature, featuring reader-submitted stories of no more than 100 words.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Tiny Love Stories: \u2018My Parents Fought a Lot\u2019",
#             "kicker": "Modern Love",
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Love (Emotion)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Modern Love (Times Column)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Dating and Relationships",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-02-07T20:00:09+0000",
#         "byline": {
#             "original": null,
#             "person": [],
#             "organization": null
#         },
#         "word_count": 476
#     }
# ]

# %%
reviews_df = pd.json_normalize(reviews_list)
reviews_df.head(10)
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/30/style/tiny-...
# 1  https://www.nytimes.com/2023/05/30/theater/her...
# 2  https://www.nytimes.com/2023/05/26/us/ken-paxt...
# 3  https://www.nytimes.com/2023/05/26/style/love-...
# 4  https://www.nytimes.com/2023/05/26/theater/asp...
# 5  https://www.nytimes.com/2023/05/26/style/trist...
# 6  https://www.nytimes.com/2023/05/25/arts/music/...
# 7  https://www.nytimes.com/2023/05/25/arts/music/...
# 8  https://www.nytimes.com/2023/05/25/movies/the-...
# 9  https://www.nytimes.com/2023/05/25/books/revie...
#
#                                              snippet              source  \
# 0  Modern Love in miniature, featuring reader-sub...  The New York Times
# 1  The show plans to use recorded music instead o...  The New York Times
# 2  With the Texas House set to vote on his impeac...  The New York Times
# 3  “That’s why I picked a younger man; he wouldn’...  The New York Times
# 4  A London revival of Andrew Lloyd Webber’s part...  The New York Times
# 5  Tristan Thompson and Tyla Wade’s passion for t...  The New York Times
# 6  A British Beat poet, he wrote lyrics for the b...  The New York Times
# 7  Salvatore Sciarrino’s “Venere e Adone,” his 15...  The New York Times
# 8  A gynecologist and her patient form a horrifyi...  The New York Times
# 9  “Indeed, the two have a lot in common!” says t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Love (Emotion)'...
# 1  [{'name': 'subject', 'value': 'Theater', 'rank...
# 2  [{'name': 'persons', 'value': 'Paxton, Ken', '...
# 3  [{'name': 'subject', 'value': 'Dating and Rela...
# 4  [{'name': 'subject', 'value': 'Theater', 'rank...
# 5  [{'name': 'subject', 'value': 'Weddings and En...
# 6  [{'name': 'persons', 'value': 'Brown, Pete (19...
# 7  [{'name': 'subject', 'value': 'Opera', 'rank':...
# 8  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 9  [{'name': 'subject', 'value': 'Books and Liter...
#
#                    pub_date  word_count  \
# 0  2023-05-30T19:00:20+0000         484
# 1  2023-05-30T17:01:03+0000         600
# 2  2023-05-26T23:36:08+0000        1532
# 3  2023-05-26T20:41:20+0000         148
# 4  2023-05-26T15:55:52+0000         800
# 5  2023-05-26T04:00:41+0000        1661
# 6  2023-05-25T20:01:09+0000        1154
# 7  2023-05-25T19:26:36+0000        1216
# 8  2023-05-25T11:00:03+0000         295
# 9  2023-05-25T09:00:09+0000        1127
#
#                                        headline.main headline.kicker  \
# 0         Tiny Love Stories: ‘Everyone Knew but Him’     Modern Love
# 1  Broadway Musicians Object to David Byrne’s ‘He...            None
# 2  How Fighting for Conservative Causes Has Helpe...            None
# 3                  Love Letter: Not Part of the Plan            None
# 4  Review: Problematic Attachments in ‘Aspects of...            None
# 5  A Union That Felt Like ‘a Love Letter to Black...            Vows
# 6  Pete Brown, Who Put Words to ‘Sunshine of Your...            None
# 7  An Opera Composer of Intimate Spareness Return...            None
# 8        ‘The Attachment Diaries’ Review: Love, Sick            None
# 9  Brandon Taylor Loves to Read Romances and Euro...     By the Book
#
#   headline.content_kicker                            headline.print_headline  \
# 0                    None                                               None
# 1                    None  Broadway Musicians Object to David Byrne’s ‘He...
# 2                    None  The Right’s Love Helps a Texas Official in a Bind
# 3                    None                                               None
# 4                    None                                               None
# 5                    None  Their Union Felt Like ‘a Love Letter to Black ...
# 6                    None  Pete Brown, 82, Poet   Who Wrote the Lyrics To...
# 7                    None                   When Love Takes Aim At a Monster
# 8                    None                             The Attachment Diaries
# 9                    None                                     Brandon Taylor
#
#   headline.name headline.seo headline.sub         byline.original  \
# 0          None         None         None                    None
# 1          None         None         None      By Michael Paulson
# 2          None         None         None     By J. David Goodman
# 3          None         None         None             By Miya Lee
# 4          None         None         None       By Houman Barekat
# 5          None         None         None         By Sadiba Hasan
# 6          None         None         None     By Richard Sandomir
# 7          None         None         None   By Jeffrey Arlo Brown
# 8          None         None         None  By Jeannette Catsoulis
# 9          None         None         None                    None
#
#                                        byline.person byline.organization
# 0                                                 []                None
# 1  [{'firstname': 'Michael', 'middlename': None, ...                None
# 2  [{'firstname': 'J.', 'middlename': 'David', 'l...                None
# 3  [{'firstname': 'Miya', 'middlename': None, 'la...                None
# 4  [{'firstname': 'Houman', 'middlename': None, '...                None
# 5  [{'firstname': 'Sadiba', 'middlename': None, '...                None
# 6  [{'firstname': 'Richard', 'middlename': None, ...                None
# 7  [{'firstname': 'Jeffrey', 'middlename': 'Arlo'...                None
# 8  [{'firstname': 'Jeannette', 'middlename': None...                None
# 9                                                 []                None

# %%
# Create an empty list to store the reviews


# loop through pages 0-19

    # create query with a page number
    # API results show 10 articles at a time

    
    # Make a "GET" request and retrieve the JSON

    
    # Add a twelve second interval between queries to stay within API query limits

    
    # Try and save the reviews to the reviews_list

        # loop through the reviews["response"]["docs"] and append each review to the list

        # Print the page that was just retrieved


        # Print the page number that had no results then break from the loop
# Out:
# Checked page 0
# Checked page 1
# Checked page 2
# Checked page 3
# Checked page 4
# Checked page 5
# Checked page 6
# Checked page 7
# Checked page 8
# Checked page 9
# Checked page 10
# Checked page 11
# Checked page 12
# Checked page 13
# Checked page 14
# Checked page 15
# Checked page 16
# Checked page 17
# Checked page 18
# Checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'creative_works', 'value': 'Love & T...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'creative_works', 'value': 'Kedi (Mo...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 The Other Half
# 196                         The Ottoman Lieutenant
# 197                                   Love & Taxes
# 198  Everybody Loves Somebody,’ a Rom-Com With Bit
# 199              Kedi,’ Rekindling a ‘Love of Life
#
# [200 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# 3    Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4    A radiant Virginie Efira stars as a Parisian t...  The New York Times
# ..                                                 ...                 ...
# 195  This moody romance stars Tatiana Maslany (“Orp...  The New York Times
# 196  A nurse travels to the Ottoman Empire on the e...  The New York Times
# 197  Josh Kornbluth runs afoul of the Internal Reve...  The New York Times
# 198  A messed-up heroine is asked to choose between...  The New York Times
# 199  This documentary profiles distinctive street c...  The New York Times
#
#                                               keywords  \
# 0    subject: Movies;creative_works: The Attachment...
# 1    subject: Movies;persons: Kapur, Shekhar;person...
# 2    subject: Movies;creative_works: You Can Live F...
# 3    subject: Movies;creative_works: A Tourist's Gu...
# 4    subject: Movies;persons: Zlotowski, Rebecca;cr...
# ..                                                 ...
# 195  subject: Movies;creative_works: The Other Half...
# 196  subject: Movies;creative_works: The Ottoman Li...
# 197  creative_works: Love & Taxes (Movie);persons: ...
# 198  subject: Movies;creative_works: Everybody Love...
# 199  creative_works: Kedi (Movie);subject: Document...
#
#                      pub_date  word_count  \
# 0    2023-05-25T11:00:03+0000         295
# 1    2023-05-04T17:16:45+0000         287
# 2    2023-05-04T11:00:08+0000         294
# 3    2023-04-21T07:03:25+0000         276
# 4    2023-04-20T15:35:13+0000         801
# ..                        ...         ...
# 195  2017-03-09T21:54:58+0000         251
# 196  2017-03-09T21:53:12+0000         267
# 197  2017-03-02T21:44:18+0000         246
# 198  2017-02-16T21:45:50+0000         256
# 199  2017-02-09T16:21:39+0000         274
#
#                                          headline.main headline.kicker  \
# 0          ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2    ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3    ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4       ‘Other People’s Children’ Review: True Romance   Critic’s pick
# ..                                                 ...             ...
# 195  Review: A Combustible Pair Find Love in ‘The O...            None
# 196  Review: Love as the World Wars, in ‘The Ottoma...            None
# 197  Review: It’s All Mirth and Taxes in ‘Love & Ta...            None
# 198  Review: ‘Everybody Loves Somebody,’ a Rom-Com ...            None
# 199  Review: Cute Cats of ‘Kedi,’ Rekindling a ‘Lov...            None
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                       What’s Love Got to Do With It?          None
# 2                                 You Can Live Forever          None
# 3                           A Tourist’s  Guide to Love          None
# 4               Intoxicating Love With a Sobering Turn          None
# ..                                                 ...           ...
# 195  Review: A Combustible Pair Find Love in ‘The O...          None
# 196  Review: Love as the World Wars, in ‘The Ottoma...          None
# 197                   It’s Inevitable, Mirth and Taxes          None
# 198                           Everybody Loves Somebody          None
# 199                                               Kedi          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None    By Jeannette Catsoulis
# 2           None         None  By Elisabeth Vincentelli
# 3           None         None  By Elisabeth Vincentelli
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 195         None         None           By Andy Webster
# 196         None         None        By Neil Genzlinger
# 197         None         None         By Ken Jaworowski
# 198         None         None    By Jeannette Catsoulis
# 199         None         None            By Glenn Kenny
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Jeannette', 'middlename': None...                None
# 2    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 196  [{'firstname': 'Neil', 'middlename': None, 'la...                None
# 197  [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 198  [{'firstname': 'Jeannette', 'middlename': None...                None
# 199  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
#
#                                              title
# 0                           The Attachment Diaries
# 1    What’s Love Got to Do With It?’ Probably a Lo
# 2                             You Can Live Forever
# 3                        A Tourist’s Guide to Love
# 4                          Other People’s Children
# ..                                             ...
# 195                                 The Other Half
# 196                         The Ottoman Lieutenant
# 197                                   Love & Taxes
# 198  Everybody Loves Somebody,’ a Rom-Com With Bit
# 199              Kedi,’ Rekindling a ‘Love of Life
#
# [200 rows x 17 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
#  'Cyrano',
#  'The In Between',
#  'Book of Love',
#  'Lingui, the Sacred Bonds',
#  'The Pink Cloud',
#  'A Journal for Jordan',
#  'West Side Story',
#  'Aulcie',
#  'Love Is Love Is Love',
#  'Love Hard',
#  'Bergman Island',
#  'Hard Luck Love Song',
#  'South of Heaven',
#  'Wife of a Spy',
#  'Happier Than Ever',
#  'Together',
#  'Annette',
#  'Resort to Love',
#  'Woodstock 99: Peace, Love and Rage',
#  'Casanova, Last Love',
#  'Running Against the Wind',
#  'Asia',
#  'Undine',
#  'This Town',
#  'Tu Me Manques',
#  'Monday',
#  'Ride or Die',
#  'Future People',
#  'Luz',
#  'Happily',
#  'This Is the Life',
#  'To All the Boys: Always and Forever',
#  'Young Hearts',
#  'Little Fish',
#  'Two of Us',
#  'Atlantis',
#  'Preparations to Be Together',
#  'Your Name Engraved Herein',
#  'Sylvie’s Love',
#  'Ariana Grande: Excuse Me, I Love You',
#  'Museum Town',
#  'Wild Mountain Thyme',
#  'My Psychedelic Love Story',
#  '69: The Saga of Danny Hernandez',
#  'Ammonite',
#  'Love and Monsters',
#  'Dick Johnson Is Dead',
#  'Love, Guaranteed',
#  'Feel the Beat',
#  'Babyteeth',
#  'Spelling the Dream',
#  'A Secret Love',
#  'Love Wedding Repeat',
#  'Almost Love',
#  'Hope Gap',
#  'All the Bright Places',
#  'The Photograph',
#  'You Go to My Head',
#  'Ordinary Love',
#  'To All the Boys: P.S. I Still Love You',
#  'The Woman Who Loves Giraffes',
#  'Queen & Slim',
#  'Marriage Story',
#  'Cyrano, My Love',
#  'Pretenders',
#  'First Love',
#  'Loro',
#  'Falling Inn Love',
#  'Hot Air',
#  'Love, Antosha',
#  'Leto',
#  'The Tomorrow Man',
#  'Asako I & II',
#  'The Sun Is Also a Star',
#  'Shéhérazade',
#  'Long Shot',
#  'Clara',
#  'Kalank',
#  'Rafiki',
#  'Diane',
#  'Five Feet Apart',
#  'Ash Is Purest White',
#  'Gloria Bell',
#  'Black Mother',
#  'The Hole in the Ground',
#  'How to Train Your Dragon: The Hidden World',
#  'A Tuba to Cuba',
#  'Fighting With My Family',
#  'Sorry Angel',
#  'Berlin, I Love You',
#  'Untogether',
#  'Cold War',
#  'If Beale Street Could Talk',
#  'Asher',
#  'The Party’s Just Beginning',
#  'The Great Pretender',
#  'Sicilian Ghost Story',
#  'The New Romantic',
#  'Pimp',
#  'In a Relationship',
#  'They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil',
#  'Burning,’ Love Ignites a Divided Worl',
#  'After Everything,’ a Young Love Blooms in Crisi',
#  'Quincy’ Captures a Lifelong Love Affair With Musi',
#  'Love, Gilda,’ a Portrait of a Brief and Brilliant Caree',
#  'Tea With the Dames,’ Four Legends Dish on Acting and Lov',
#  'Bel Canto,’ Music Is the Food of Love and Rebellio',
#  'The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov',
#  'Love, Cecil,’ an Aesthete Ahead of His Tim',
#  'How to Talk to Girls at Parties',
#  'Rogers Park,’ Life and Love in a Chicago Neighborhoo',
#  'Love & Bananas,’ Uncovering the Plight of the Asian Elephan',
#  'Godard Mon Amour',
#  'Submergence,’ a Love Story Sunk by Geopolitic',
#  'Love After Love,’ an Unflinching Look at Extended Grie',
#  'Outside In',
#  'Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre',
#  'Keep the Change,’ Two People With Autism Find Lov',
#  'The Party',
#  'The Housemaid,’ Twisted Love and Angry Ghosts in Vietna',
#  'Forever My Girl,’ a Romance Resumes After a Long Brea',
#  'Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr',
#  'Lover for a Day',
#  'Youth,’ the People’s Dance Troupe, in Love and Wa',
#  'Killing for Love’ Revisits a Virginia Murder Cas',
#  'The Shape of Water’ Is Altogether Wonderfu',
#  'Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr',
#  'Cuba and the Cameraman’ Lavishes Love on a Country … and Castr',
#  'On the Beach at Night Alone’ Zooms in on a Love Affai',
#  'Thelma,’ a Woman in Love Can Burn Down the Worl',
#  'Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade',
#  'It Happened in L.A.,’ All That Questing After Lov',
#  'God’s Own Country',
#  'The Mountain Between Us',
#  'Dina,’ a Differently Abled Love Stor',
#  'In Search of Fellini',
#  'Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen',
#  'I Do ... Until I Don’t,’ Love and Loathing in Florid',
#  'Tales of an Immoral Couple’: Love Means Having to Grow U',
#  'After Love’ and Regretting Every Momen',
#  'The Last Face',
#  'Women Who Kill,’ and May Be in Love With On',
#  'False Confessions,’ the Play’s Not Quite the Thin',
#  'Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem',
#  'The Big Sick,’ Comedy Is Hard, Love Harde',
#  'Lost in Paris',
#  'Vincent N Roxxy,’ Love Is in the Air, N So Is Fea',
#  'Everything, Everything’ Pits Love Against Diseas',
#  'Hounds of Love’ Is Tense and Deadly Down Unde',
#  'Harold and Lillian’ Introduces a Hollywood Power Coupl',
#  'The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope',
#  'The Promise’ Finds a Love Triangle in Constantinopl',
#  'Frantz,’ a Mysterious Frenchman and the Wounds of Wa',
#  'The Other Half',
#  'The Ottoman Lieutenant',
#  'Love & Taxes',
#  'Everybody Loves Somebody,’ a Rom-Com With Bit',
#  'Kedi,’ Rekindling a ‘Love of Life']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results


# Create a request counter to sleep the requests after a multiple
# of 50 requests


# Loop through the titles

    # Check if we need to sleep before making a request


    # Add 1 to the request counter

    
    # Perform a "GET" request for The Movie Database


    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.

        # Get movie id


        # Make a request for a the full movie details


        # Execute "GET" request with url

        
        # Extract the genre names into a list


        # Extract the spoken_languages' English name into a list


        # Extract the production_countries' name into a list


        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list

        
        # Print out the title that was found
# Out:
# Found The Attachment Diaries
# What’s Love Got to Do With It?’ Probably a Lo not found.
# Found You Can Live Forever
# Found A Tourist’s Guide to Love
# Found Other People’s Children
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found About Fate
# Found Waiting for Bojangles
# Found I Love My Dad
# Found A Love Song
# Found Alone Together
# Found Art of Love
# Found The Wheel
# Found Thor: Love and Thunder
# Found Both Sides of the Blade
# Found Fire of Love
# Found Love & Gelato
# Found Stay Prayed Up
# Found Benediction
# Found Dinner in America
# Found In a New York Minute
# Found Anaïs in Love
# Found I Love America
# Found See You Then
# Found La Mami
# Found Love After Love
# Found Deep Water
# Found Lucy and Desi
# Found Cyrano
# Found The In Between
# Found Book of Love
# Found Lingui, the Sacred Bonds
# Found The Pink Cloud
# Found A Journal for Jordan
# Found West Side Story
# Sleeping at 50 requests
# Found Aulcie
# Found Love Is Love Is Love
# Found Love Hard
# Found Bergman Island
# Found Hard Luck Love Song
# Found South of Heaven
# Found Wife of a Spy
# Found Happier Than Ever
# Found Together
# Found Annette
# Found Resort to Love
# Found Woodstock 99: Peace, Love and Rage
# Found Casanova, Last Love
# Found Running Against the Wind
# Found Asia
# Found Undine
# Found This Town
# Found Tu Me Manques
# Found Monday
# Found Ride or Die
# Found Future People
# Found Luz
# Found Happily
# Found This Is the Life
# Found To All the Boys: Always and Forever
# Found Young Hearts
# Found Little Fish
# Found Two of Us
# Found Atlantis
# Found Preparations to Be Together
# Found Your Name Engraved Herein
# Found Sylvie’s Love
# Found Ariana Grande: Excuse Me, I Love You
# Found Museum Town
# Found Wild Mountain Thyme
# Found My Psychedelic Love Story
# Found 69: The Saga of Danny Hernandez
# Found Ammonite
# Found Love and Monsters
# Found Dick Johnson Is Dead
# Found Love, Guaranteed
# Found Feel the Beat
# Found Babyteeth
# Found Spelling the Dream
# Found A Secret Love
# Found Love Wedding Repeat
# Found Almost Love
# Found Hope Gap
# Found All the Bright Places
# Found The Photograph
# Sleeping at 100 requests
# Found You Go to My Head
# Found Ordinary Love
# Found To All the Boys: P.S. I Still Love You
# Found The Woman Who Loves Giraffes
# Found Queen & Slim
# Found Marriage Story
# Found Cyrano, My Love
# Found Pretenders
# Found First Love
# Found Loro
# Found Falling Inn Love
# Found Hot Air
# Found Love, Antosha
# Found Leto
# Found The Tomorrow Man
# Found Asako I & II
# Found The Sun Is Also a Star
# Found Shéhérazade
# Found Long Shot
# Found Clara
# Found Kalank
# Found Rafiki
# Found Diane
# Found Five Feet Apart
# Found Ash Is Purest White
# Found Gloria Bell
# Found Black Mother
# Found The Hole in the Ground
# Found How to Train Your Dragon: The Hidden World
# Found A Tuba to Cuba
# Found Fighting With My Family
# Found Sorry Angel
# Found Berlin, I Love You
# Found Untogether
# Found Cold War
# Found If Beale Street Could Talk
# Found Asher
# Found The Party’s Just Beginning
# Found The Great Pretender
# Found Sicilian Ghost Story
# Found The New Romantic
# Found Pimp
# Found In a Relationship
# They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil not found.
# Burning,’ Love Ignites a Divided Worl not found.
# After Everything,’ a Young Love Blooms in Crisi not found.
# Quincy’ Captures a Lifelong Love Affair With Musi not found.
# Love, Gilda,’ a Portrait of a Brief and Brilliant Caree not found.
# Tea With the Dames,’ Four Legends Dish on Acting and Lov not found.
# Bel Canto,’ Music Is the Food of Love and Rebellio not found.
# Sleeping at 150 requests
# The Citizen,’ an Immigrant Picks a Bad Time to Fall in Lov not found.
# Love, Cecil,’ an Aesthete Ahead of His Tim not found.
# Found How to Talk to Girls at Parties
# Rogers Park,’ Life and Love in a Chicago Neighborhoo not found.
# Found Love & Bananas,’ Uncovering the Plight of the Asian Elephan
# Found Godard Mon Amour
# Submergence,’ a Love Story Sunk by Geopolitic not found.
# Love After Love,’ an Unflinching Look at Extended Grie not found.
# Found Outside In
# Love, Simon,’ a Glossy Teen Romance, the Hero Has a Secre not found.
# Keep the Change,’ Two People With Autism Find Lov not found.
# Found The Party
# The Housemaid,’ Twisted Love and Angry Ghosts in Vietna not found.
# Forever My Girl,’ a Romance Resumes After a Long Brea not found.
# Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr not found.
# Found Lover for a Day
# Youth,’ the People’s Dance Troupe, in Love and Wa not found.
# Killing for Love’ Revisits a Virginia Murder Cas not found.
# The Shape of Water’ Is Altogether Wonderfu not found.
# Love Beats Rhymes,’ a Hip-Hop Artist Transformed by Poetr not found.
# Cuba and the Cameraman’ Lavishes Love on a Country … and Castr not found.
# On the Beach at Night Alone’ Zooms in on a Love Affai not found.
# Thelma,’ a Woman in Love Can Burn Down the Worl not found.
# Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade not found.
# It Happened in L.A.,’ All That Questing After Lov not found.
# Found God’s Own Country
# Found The Mountain Between Us
# Dina,’ a Differently Abled Love Stor not found.
# Found In Search of Fellini
# Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen not found.
# I Do ... Until I Don’t,’ Love and Loathing in Florid not found.
# Tales of an Immoral Couple’: Love Means Having to Grow U not found.
# After Love’ and Regretting Every Momen not found.
# Found The Last Face
# Women Who Kill,’ and May Be in Love With On not found.
# False Confessions,’ the Play’s Not Quite the Thin not found.
# Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem not found.
# The Big Sick,’ Comedy Is Hard, Love Harde not found.
# Found Lost in Paris
# Vincent N Roxxy,’ Love Is in the Air, N So Is Fea not found.
# Everything, Everything’ Pits Love Against Diseas not found.
# Hounds of Love’ Is Tense and Deadly Down Unde not found.
# Harold and Lillian’ Introduces a Hollywood Power Coupl not found.
# The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope not found.
# The Promise’ Finds a Love Triangle in Constantinopl not found.
# Frantz,’ a Mysterious Frenchman and the Wounds of Wa not found.
# Found The Other Half
# Found The Ottoman Lieutenant
# Found Love & Taxes
# Everybody Loves Somebody,’ a Rom-Com With Bit not found.
# Sleeping at 200 requests
# Kedi,’ Rekindling a ‘Love of Life not found.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "genre": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "language": "es",
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 0.708,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 4.0,
#         "vote_count": 2,
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "You Can Live Forever",
#         "original_title": "You Can Live Forever",
#         "budget": 0,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "French",
#             "English"
#         ],
#         "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 12.027,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-03-24",
#         "vote_average": 7.643,
#         "vote_count": 21,
#         "production_countries": [
#             "Canada"
#         ]
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "original_title": "A Tourist's Guide to Love",
#         "budget": 0,
#         "genre": [
#             "Romance",
#             "Comedy",
#             "Adventure"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "English"
#         ],
#         "homepage": "https://www.netflix.com/title/81424906",
#         "overview": "After an unexpected break up, a travel executive accepts an assignment to go undercover and learn about the tourist industry in Vietnam. Along the way, she finds adventure and romance with her Vietnamese expat tour guide and they decide to hijack the tour bus in order to explore life and love off the beaten path.",
#         "popularity": 25.369,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2023-04-21",
#         "vote_average": 6.389,
#         "vote_count": 122,
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Other People's Children",
#         "original_title": "Les Enfants des autres",
#         "budget": 0,
#         "genre": [
#             "Drama"
#         ],
#         "language": "fr",
#         "spoken_languages": [
#             "French"
#         ],
#         "homepage": "https://www.wildbunch.biz/movie/other-peoples-children/",
#         "overview": "Rachel loves her life, her students, her friends, her ex, her guitar lessons. When she falls in love with Ali, she grows close to his 4-year-old daughter, Leila. She tucks her in, looks after her, and loves her like a mother... which she isn\u2019t. Not yet. Rachel is 40. The desire for a family of her own is growing stronger, and the clock is ticking. Is it too late?",
#         "popularity": 16.246,
#         "runtime": 104,
#         "revenue": 0,
#         "release_date": "2022-09-21",
#         "vote_average": 6.9,
#         "vote_count": 137,
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "One True Loves",
#         "original_title": "One True Loves",
#         "budget": 0,
#         "genre": [
#             "Romance",
#             "Drama",
#             "Comedy"
#         ],
#         "language": "en",
#         "spoken_languages": [
#             "English"
#         ],
#         "homepage": "",
#         "overview": "Emma and Jesse are living the perfect life together, until Jesse disappears in a tragic helicopter crash on their first wedding anniversary. Four years later, Emma has found happiness again and is about to marry her best friend when Jesse resurfaces, turning her world upside down and leaving her torn between two great loves.",
#         "popularity": 28.872,
#         "runtime": 100,
#         "revenue": 37820,
#         "release_date": "2023-04-07",
#         "vote_average": 6.681,
#         "vote_count": 36,
#         "production_countries": [
#             "Germany",
#             "United States of America"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
# Out:
#                          title             original_title    budget  \
# 0       The Attachment Diaries                   El apego         0
# 1         You Can Live Forever       You Can Live Forever         0
# 2    A Tourist's Guide to Love  A Tourist's Guide to Love         0
# 3      Other People's Children     Les Enfants des autres         0
# 4               One True Loves             One True Loves         0
# ..                         ...                        ...       ...
# 150              The Last Face              The Last Face         0
# 151              Lost in Paris            Paris pieds nus         0
# 152             The Other Half             The Other Half         0
# 153     The Ottoman Lieutenant     The Ottoman Lieutenant  40000000
# 154             Rich in Love 2            Ricos de Amor 2         0
#
#                                   genre language       spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]       es              [Spanish]
# 1                      [Drama, Romance]       en      [French, English]
# 2          [Romance, Comedy, Adventure]       en              [English]
# 3                               [Drama]       fr               [French]
# 4              [Romance, Drama, Comedy]       en              [English]
# ..                                  ...      ...                    ...
# 150                             [Drama]       en  [English, Portuguese]
# 151                            [Comedy]       fr               [French]
# 152            [Drama, Comedy, Romance]       en              [English]
# 153               [Romance, Drama, War]       en     [English, Turkish]
# 154                   [Romance, Comedy]       pt           [Portuguese]
#
#                                               homepage  \
# 0
# 1    https://gooddeedentertainment.com/you-can-live...
# 2               https://www.netflix.com/title/81424906
# 3    https://www.wildbunch.biz/movie/other-peoples-...
# 4
# ..                                                 ...
# 150
# 151
# 152
# 153  https://www.uphe.com/movies/the-ottoman-lieute...
# 154
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1    When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2    After an unexpected break up, a travel executi...      25.369       96
# 3    Rachel loves her life, her students, her frien...      16.246      104
# 4    Emma and Jesse are living the perfect life tog...      28.872      100
# ..                                                 ...         ...      ...
# 150  Miguel, a heroic Spanish doctor, puts himself ...       9.081      130
# 151  Fiona visits Paris for the first time to assis...       6.798       83
# 152  When English Mark surprises his American bride...       1.058       94
# 153  Lillie, a determined American woman, ventures ...      12.097      111
# 154  When the idealistic Paula resumes her work as ...      33.808       89
#
#      revenue release_date  vote_average  vote_count  \
# 0          0   2021-10-07         4.000           2
# 1          0   2023-03-24         7.643          21
# 2          0   2023-04-21         6.389         122
# 3          0   2022-09-21         6.900         137
# 4      37820   2023-04-07         6.681          36
# ..       ...          ...           ...         ...
# 150        0   2017-01-11         5.617         184
# 151        0   2017-01-14         6.051         108
# 152        0   2006-05-15         6.708          12
# 153   413844   2017-03-10         6.150         236
# 154        0   2023-06-02         6.925          60
#
#                     production_countries
# 0                            [Argentina]
# 1                               [Canada]
# 2             [United States of America]
# 3                               [France]
# 4    [Germany, United States of America]
# ..                                   ...
# 150           [United States of America]
# 151                    [Belgium, France]
# 152                     [United Kingdom]
# 153   [Turkey, United States of America]
# 154                             [Brazil]
#
# [155 rows x 15 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
# Out:
#                               title                  original_title    budget  \
# 0            The Attachment Diaries                        El apego         0
# 1              You Can Live Forever            You Can Live Forever         0
# 2                    One True Loves                  One True Loves         0
# 3    The Lost Weekend: A Love Story  The Lost Weekend: A Love Story         0
# 4                A Thousand and One              A Thousand and One         0
# ..                              ...                             ...       ...
# 120            In Search of Fellini            In Search of Fellini         0
# 121                   The Last Face                   The Last Face         0
# 122                   Lost in Paris                 Paris pieds nus         0
# 123                  The Other Half                  The Other Half         0
# 124          The Ottoman Lieutenant          The Ottoman Lieutenant  40000000
#
#                                   genre language       spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]       es              [Spanish]
# 1                      [Drama, Romance]       en      [French, English]
# 2              [Romance, Drama, Comedy]       en              [English]
# 3                         [Documentary]       en                     []
# 4                               [Drama]       en              [English]
# ..                                  ...      ...                    ...
# 120                  [Drama, Adventure]       en              [English]
# 121                             [Drama]       en  [English, Portuguese]
# 122                            [Comedy]       fr               [French]
# 123            [Drama, Comedy, Romance]       en              [English]
# 124               [Romance, Drama, War]       en     [English, Turkish]
#
#                                               homepage  \
# 0
# 1    https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4    https://www.focusfeatures.com/a-thousand-and-one/
# ..                                                 ...
# 120
# 121
# 122
# 123
# 124  https://www.uphe.com/movies/the-ottoman-lieute...
#
#                                               overview  popularity  runtime  \
# 0    Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1    When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2    Emma and Jesse are living the perfect life tog...      28.872      100
# 3    May Pang lovingly recounts her life in rock & ...       2.368       97
# 4    Struggling but unapologetically living on her ...      11.704      116
# ..                                                 ...         ...      ...
# 120  Lucy, a small-town girl from Ohio, discovers t...       4.103       93
# 121  Miguel, a heroic Spanish doctor, puts himself ...       9.081      130
# 122  Fiona visits Paris for the first time to assis...       6.798       83
# 123  When English Mark surprises his American bride...       1.058       94
# 124  Lillie, a determined American woman, ventures ...      12.097      111
#
#      ...                                      headline.main headline.kicker  \
# 0    ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1    ...  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2    ...     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3    ...  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4    ...  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
# ..   ...                                                ...             ...
# 120  ...  Review: Love of Il Maestro Drives ‘In Search o...            None
# 121  ...  Review: Aid Workers in Love and War in Sean Pe...            None
# 122  ...  Review: Finding Love (and Slapstick) While ‘Lo...            None
# 123  ...  Review: A Combustible Pair Find Love in ‘The O...            None
# 124  ...  Review: Love as the World Wars, in ‘The Ottoma...            None
#
#      headline.content_kicker  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ..                       ...
# 120                     None
# 121                     None
# 122                     None
# 123                     None
# 124                     None
#
#                                headline.print_headline headline.name  \
# 0                               The Attachment Diaries          None
# 1                                 You Can Live Forever          None
# 2                                       One True Loves          None
# 3                      The Lost Weekend:  A Love Story          None
# 4              An Unbending Will Meets a Shifting City          None
# ..                                                 ...           ...
# 120                               In Search of Fellini          None
# 121                                      The Last Face          None
# 122                                      Lost in Paris          None
# 123  Review: A Combustible Pair Find Love in ‘The O...          None
# 124  Review: Love as the World Wars, in ‘The Ottoma...          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None  By Elisabeth Vincentelli
# 2           None         None             By Brandon Yu
# 3           None         None            By Glenn Kenny
# 4           None         None         By Manohla Dargis
# ..           ...          ...                       ...
# 120         None         None        By Monica Castillo
# 121         None         None            By Glenn Kenny
# 122         None         None         By Ben Kenigsberg
# 123         None         None           By Andy Webster
# 124         None         None        By Neil Genzlinger
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2    [{'firstname': 'Brandon', 'middlename': None, ...                None
# 3    [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4    [{'firstname': 'Manohla', 'middlename': None, ...                None
# ..                                                 ...                 ...
# 120  [{'firstname': 'Monica', 'middlename': None, '...                None
# 121  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 122  [{'firstname': 'Ben', 'middlename': None, 'las...                None
# 123  [{'firstname': 'Andy', 'middlename': None, 'la...                None
# 124  [{'firstname': 'Neil', 'middlename': None, 'la...                None
#
# [125 rows x 31 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1  When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2  Emma and Jesse are living the perfect life tog...      28.872      100
# 3  May Pang lovingly recounts her life in rock & ...       2.368       97
# 4  Struggling but unapologetically living on her ...      11.704      116
#
#    ...                                      headline.main headline.kicker  \
# 0  ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ...  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2  ...     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ...  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ...  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#    headline.content_kicker                  headline.print_headline  \
# 0                     None                   The Attachment Diaries
# 1                     None                     You Can Live Forever
# 2                     None                           One True Loves
# 3                     None          The Lost Weekend:  A Love Story
# 4                     None  An Unbending Will Meets a Shifting City
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None  By Elisabeth Vincentelli
# 2          None         None         None             By Brandon Yu
# 3          None         None         None            By Glenn Kenny
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 3  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
# [5 rows x 31 columns]

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1  When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2  Emma and Jesse are living the perfect life tog...      28.872      100
# 3  May Pang lovingly recounts her life in rock & ...       2.368       97
# 4  Struggling but unapologetically living on her ...      11.704      116
#
#    ...  word_count                                      headline.main  \
# 0  ...         295        ‘The Attachment Diaries’ Review: Love, Sick
# 1  ...         294  ‘You Can Live Forever’ Review: Do You Love Me ...
# 2  ...         320     ‘One True Loves’ Review: A Romance Lost at Sea
# 3  ...         327  ‘The Lost Weekend: A Love Story’ Review: When ...
# 4  ...         971  ‘A Thousand and One’ Review: A New York Love S...
#
#    headline.kicker  headline.content_kicker  \
# 0             None                     None
# 1             None                     None
# 2             None                     None
# 3             None                     None
# 4    Critic’s Pick                     None
#
#                    headline.print_headline headline.name headline.seo  \
# 0                   The Attachment Diaries          None         None
# 1                     You Can Live Forever          None         None
# 2                           One True Loves          None         None
# 3          The Lost Weekend:  A Love Story          None         None
# 4  An Unbending Will Meets a Shifting City          None         None
#
#   headline.sub           byline.original byline.organization
# 0         None    By Jeannette Catsoulis                None
# 1         None  By Elisabeth Vincentelli                None
# 2         None             By Brandon Yu                None
# 3         None            By Glenn Kenny                None
# 4         None         By Manohla Dargis                None
#
# [5 rows x 30 columns]

# %%
# Export data to CSV without the index
